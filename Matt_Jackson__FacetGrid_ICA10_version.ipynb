# %% [markdown]
# <a href="https://colab.research.google.com/github/maja74maja74/CSC302_ICA10/blob/main/Matt_Jackson__FacetGrid_ICA10_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *   Please read titanic.csv from the DATA folder
# *   Change 1s to "Survived" under the Survived column of the data frame by looking at the example provided.
# *   Get rows which don't have "?" under Pclass column and move to the next step.

# %%
titanic = pd.read_csv("/content/drive/MyDrive/DATA/titanic.csv")
titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
titanic.loc[titanic["Survived"] == 1, "Survived"] = "Survived"

# %%
t2 = titanic[pd.to_numeric(titanic['Pclass'], errors='coerce').notnull()]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a multipanel plot which draws density plots for each class-survived combination. Please also use the hue parameter based on the Sex attribute to have two density plots in each panel with different colors.

# %%
t2 = t2.astype({'Pclass':'int'})
g = sns.FacetGrid(t2, col="Pclass",  row="Survived", hue= "Sex")
g.map(sns.kdeplot(data=t2, x= 'Pclass', ))
#you can uncomment below when you come up with your density plots for each class-survived combination
titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
for ax,title in zip(g.axes.flatten(),titles):
    ax.set_title(title )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-ff30c907ac81> in <cell line: 3>()
#       1 t2 = t2.astype({'Pclass':'int'})
#       2 g = sns.FacetGrid(t2, col="Pclass",  row="Survived", hue= "Sex")
# ----> 3 g.map(sns.kdeplot(data=t2, x= 'Pclass', ))
#       4 #you can uncomment below when you come up with your density plots for each class-survived combination
#       5 titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
#
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     750
#     751             # Draw the plot
# --> 752             self._facet_plot(func, ax, plot_args, kwargs)
#     753
#     754         # Finalize the annotations and layout
#
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846             plot_args = []
#     847             plot_kwargs["ax"] = ax
# --> 848         func(*plot_args, **plot_kwargs)
#     849
#     850         # Sort out the supporting information
#
# TypeError: 'Axes' object is not callable

# %%
# !pip install joypy

# %%
from matplotlib import legend
import joypy
import matplotlib.pyplot as plt
# %matplotlib inline
t2 = t2.astype({'Pclass':'int'})
plt.figure()
plt.style.use('seaborn-white')
fig, axes = joypy.joyplot(t2, column=["Survived", "Pclass"], by="Sex", legend= 'True')
plt.show()
# Out:
# <ipython-input-27-8a4fc82a92c3>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
